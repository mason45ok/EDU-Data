# %%
#! pip install librosa
# Out:
# Requirement already satisfied: soundfile in c:\users\mason\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.12.1)
# Requirement already satisfied: cffi>=1.0 in c:\users\mason\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from soundfile) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\mason\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cffi>=1.0->soundfile) (2.21)

# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
import soundfile as sf

# 加载音频文件
data, sampling_rate = librosa.load('audio.wav', sr=None)

# 生成时间向量
time = np.arange(len(data)) / sampling_rate

# 设置调制频率和振幅
modulation_frequency = 0.5
modulation_amplitude = 0.5

# 对音频数据进行调制
modulated_data = data * (1 + modulation_amplitude * np.sin(2 * np.pi * modulation_frequency * time))

# 绘制调制后的音频波形
plt.figure(figsize=(12, 4))
plt.plot(time, modulated_data)
plt.title('Modulated Audio Waveform')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# 保存调制后的音频文件
sf.write('modulated_file.wav', modulated_data, sampling_rate)
